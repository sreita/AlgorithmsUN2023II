# %% [markdown]
# <a href="https://colab.research.google.com/github/sreita/AlgorithmsUN2024I/blob/main/LabML/ML_Max_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learning to find the máximum with a Neural Network (MLPRegressor)

# %%
import random as rnd
import numpy as np

n=10
Nexamples=1000

X =[]
y =[]
for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

# %%
import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y]})
data
# Out:
#                                   X  y
# 0    [3, 5, 2, 8, 0, 6, 7, 1, 9, 4]  9
# 1    [0, 7, 8, 9, 4, 6, 5, 1, 3, 2]  9
# 2    [1, 4, 5, 0, 2, 8, 6, 7, 9, 3]  9
# 3    [9, 4, 5, 7, 0, 8, 1, 6, 2, 3]  9
# 4    [7, 1, 6, 4, 8, 5, 0, 2, 3, 9]  9
# ..                              ... ..
# 995  [4, 9, 3, 6, 8, 2, 0, 1, 5, 7]  9
# 996  [6, 1, 2, 7, 3, 0, 5, 9, 4, 8]  9
# 997  [5, 0, 7, 4, 3, 2, 8, 9, 1, 6]  9
# 998  [0, 7, 3, 8, 9, 5, 4, 1, 2, 6]  9
# 999  [3, 2, 1, 7, 4, 0, 6, 9, 8, 5]  9
#
# [1000 rows x 2 columns]

# %%
from sklearn.neural_network import MLPRegressor
model = MLPRegressor(hidden_layer_sizes=(100,50,20),random_state=1, max_iter=1000, activation='logistic').fit(X,y)
y_pred =model.predict(X)

import matplotlib.pyplot as plt
plt.plot(model.loss_curve_)
plt.show()

# %%
import pandas as pd
y_p = pd.DataFrame({'y_pred':[ round(pred,3) for pred in y_pred]})
y_p
# Out:
#      y_pred
# 0      8.96
# 1      8.96
# 2      8.96
# 3      8.96
# 4      8.96
# ..      ...
# 995    8.96
# 996    8.96
# 997    8.96
# 998    8.96
# 999    8.96
#
# [1000 rows x 1 columns]

# %%
import random as rnd
import numpy as np

n=10
Nexamples=1000

X =[]
y =[]
for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

y_pred = model.predict(X)

import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
#                                   X  y  y_pred
# 0    [6, 3, 2, 8, 1, 5, 0, 7, 9, 4]  9       9
# 1    [1, 9, 8, 0, 2, 5, 4, 6, 3, 7]  9       9
# 2    [1, 0, 9, 7, 6, 3, 8, 4, 5, 2]  9       9
# 3    [9, 7, 3, 8, 4, 5, 1, 2, 0, 6]  9       9
# 4    [9, 1, 4, 2, 7, 3, 0, 8, 6, 5]  9       9
# ..                              ... ..     ...
# 995  [4, 0, 1, 5, 6, 3, 8, 2, 9, 7]  9       9
# 996  [9, 0, 1, 2, 6, 5, 4, 8, 3, 7]  9       9
# 997  [4, 0, 3, 9, 2, 7, 1, 8, 5, 6]  9       9
# 998  [4, 1, 9, 6, 0, 5, 2, 3, 8, 7]  9       9
# 999  [0, 4, 1, 5, 8, 7, 6, 9, 3, 2]  9       9
#
# [1000 rows x 3 columns]

# %%
import random as rnd
import numpy as np

n=10
Nexamples=1000

X =[]
y =[]
for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

y_pred = model.predict(X)

import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [pred for pred in y_pred]})
data
# Out:
#                                        X   y    y_pred
# 0    [12, 8, 6, 10, 16, 0, 18, 4, 14, 2]  18  8.960204
# 1    [0, 6, 10, 18, 14, 2, 16, 8, 12, 4]  18  8.960211
# 2    [4, 12, 10, 18, 16, 2, 14, 0, 6, 8]  18  8.960203
# 3    [10, 2, 6, 4, 0, 8, 18, 12, 14, 16]  18  8.960206
# 4    [6, 18, 0, 8, 2, 4, 16, 14, 10, 12]  18  8.960203
# ..                                   ...  ..       ...
# 995  [0, 8, 2, 6, 16, 10, 4, 18, 14, 12]  18  8.960199
# 996  [16, 12, 6, 18, 8, 0, 2, 10, 14, 4]  18  8.960206
# 997  [14, 12, 6, 16, 4, 10, 8, 2, 0, 18]  18  8.960198
# 998  [14, 6, 2, 16, 10, 4, 8, 12, 18, 0]  18  8.960207
# 999  [10, 0, 4, 14, 2, 6, 12, 18, 16, 8]  18  8.960210
#
# [1000 rows x 3 columns]

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=1000

X =[]
y =[]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

model = MLPRegressor(hidden_layer_sizes=(100,50,20), max_iter=1000, activation='tanh').fit(X,y)
y_pred =model.predict(X)


plt.plot(model.loss_curve_)
plt.show()

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 1.000
#                                         X   y  y_pred
# 0          [9, 1, 0, 5, 4, 2, 3, 6, 8, 7]   9       9
# 1          [8, 9, 1, 7, 3, 6, 5, 0, 4, 2]   9       9
# 2          [2, 1, 0, 9, 4, 7, 3, 5, 6, 8]   9       9
# 3          [7, 0, 2, 9, 6, 4, 1, 8, 5, 3]   9       9
# 4          [1, 9, 7, 6, 2, 8, 3, 0, 5, 4]   9       9
# ...                                   ...  ..     ...
# 1995  [2, 8, 10, 0, 6, 14, 12, 4, 16, 18]  18      18
# 1996  [2, 16, 4, 8, 18, 12, 0, 10, 6, 14]  18      18
# 1997  [12, 14, 6, 4, 10, 0, 16, 8, 18, 2]  18      18
# 1998  [2, 6, 12, 0, 16, 10, 8, 4, 18, 14]  18      18
# 1999  [18, 2, 14, 4, 12, 8, 10, 6, 0, 16]  18      18
#
# [2000 rows x 3 columns]

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=1000

X =[]
y =[]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

model = MLPRegressor(hidden_layer_sizes=(100,50,20), max_iter=1000, activation='relu').fit(X,y)
y_pred =model.predict(X)


plt.plot(model.loss_curve_)
plt.show()

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 1.000
#                                         X   y  y_pred
# 0          [4, 2, 7, 9, 1, 6, 5, 8, 3, 0]   9       9
# 1          [4, 5, 8, 2, 3, 6, 9, 7, 1, 0]   9       9
# 2          [7, 2, 1, 5, 0, 3, 6, 9, 4, 8]   9       9
# 3          [4, 6, 3, 8, 7, 5, 1, 2, 0, 9]   9       9
# 4          [6, 4, 7, 0, 2, 1, 8, 9, 3, 5]   9       9
# ...                                   ...  ..     ...
# 1995  [18, 8, 0, 14, 10, 12, 6, 16, 4, 2]  18      18
# 1996  [4, 12, 10, 14, 6, 8, 16, 2, 18, 0]  18      18
# 1997  [8, 4, 10, 6, 0, 14, 2, 12, 16, 18]  18      18
# 1998  [6, 2, 8, 0, 18, 14, 16, 4, 10, 12]  18      18
# 1999  [16, 14, 0, 12, 10, 4, 18, 8, 6, 2]  18      18
#
# [2000 rows x 3 columns]

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=10000

X =[]
y =[]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

y_pred =model.predict(X)

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 1.000
#                                          X   y  y_pred
# 0           [2, 1, 8, 5, 9, 7, 0, 3, 6, 4]   9       9
# 1           [8, 5, 6, 4, 2, 1, 3, 9, 0, 7]   9       9
# 2           [8, 4, 0, 1, 2, 7, 9, 5, 3, 6]   9       9
# 3           [8, 9, 3, 4, 5, 2, 0, 7, 1, 6]   9       9
# 4           [9, 8, 7, 4, 2, 3, 0, 5, 6, 1]   9       9
# ...                                    ...  ..     ...
# 19995  [8, 6, 12, 4, 14, 2, 10, 0, 18, 16]  18      18
# 19996  [12, 10, 2, 14, 4, 8, 16, 0, 18, 6]  18      18
# 19997  [4, 12, 2, 6, 18, 8, 16, 10, 14, 0]  18      18
# 19998  [18, 16, 14, 2, 4, 0, 6, 10, 8, 12]  18      18
# 19999  [4, 16, 0, 12, 6, 8, 10, 18, 14, 2]  18      18
#
# [20000 rows x 3 columns]

# %% [markdown]
# # Learning to find the máximum with a Classification and Regression Tree (CART)
#
# * https://towardsdatascience.com/cart-classification-and-regression-trees-for-clean-but-powerful-models-cc89e60b7a85
#
# * https://spotle.ai/feeddetails/Classification-and-Regression-Tree-CART-with-Python/3644
#
# ### Visualize a Decision Tree in 4 Ways with Scikit-Learn and Python
#
# * https://towardsdatascience.com/cart-classification-and-regression-trees-for-clean-but-powerful-models-cc89e60b7a85

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

n=10
Nexamples=1000

X =[]
y =[]

names = ["x"+str(i) for i in range(n)]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

model = DecisionTreeRegressor(max_leaf_nodes = 15).fit(X,y)

# %%
import random as rnd
import numpy as np

n=10
Nexamples=10000

X =[]
y =[]
for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))



y_pred = model.predict(X)

import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred':[int(round(pred)) for pred in y_pred]})
data
# Out:
#                                    X  y  y_pred
# 0     [3, 5, 2, 7, 6, 8, 9, 0, 4, 1]  9       9
# 1     [8, 1, 4, 7, 0, 3, 6, 9, 5, 2]  9       9
# 2     [1, 4, 6, 7, 2, 9, 5, 3, 8, 0]  9       9
# 3     [4, 6, 8, 2, 1, 0, 9, 3, 5, 7]  9       9
# 4     [7, 3, 0, 8, 6, 1, 5, 9, 2, 4]  9       9
# ...                              ... ..     ...
# 9995  [1, 8, 3, 0, 7, 5, 9, 4, 6, 2]  9       9
# 9996  [1, 8, 0, 6, 7, 4, 5, 3, 9, 2]  9       9
# 9997  [5, 6, 1, 9, 7, 4, 3, 2, 0, 8]  9       9
# 9998  [6, 3, 4, 5, 8, 7, 9, 1, 0, 2]  9       9
# 9999  [9, 7, 1, 6, 8, 4, 5, 3, 2, 0]  9       9
#
# [10000 rows x 3 columns]

# %%
from sklearn import tree

text_representation = tree.export_text(model)
print(text_representation)
# Out:
# |--- value: [9.00]

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

n=10
Nexamples=1000

X =[]
y =[]

names = ["x"+str(i) for i in range(n)]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

model = DecisionTreeRegressor(max_leaf_nodes = 50).fit(X,y)

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=10000

X =[]
y =[]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

y_pred =model.predict(X)

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred':[int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 0.999
#                                          X   y  y_pred
# 0           [0, 1, 4, 9, 7, 8, 5, 2, 3, 6]   9       9
# 1           [8, 6, 9, 2, 1, 4, 3, 0, 7, 5]   9       9
# 2           [1, 4, 7, 3, 9, 5, 6, 8, 0, 2]   9       9
# 3           [2, 9, 6, 1, 5, 7, 0, 8, 3, 4]   9       9
# 4           [4, 6, 9, 5, 2, 0, 8, 3, 7, 1]   9       9
# ...                                    ...  ..     ...
# 19995  [10, 0, 16, 8, 14, 4, 18, 2, 12, 6]  18      18
# 19996  [8, 0, 16, 12, 2, 14, 18, 6, 10, 4]  18      18
# 19997  [10, 16, 2, 4, 6, 18, 8, 0, 14, 12]  18      18
# 19998  [4, 12, 14, 6, 16, 10, 8, 18, 0, 2]  18      18
# 19999  [18, 10, 0, 12, 2, 16, 8, 4, 14, 6]  18      18
#
# [20000 rows x 3 columns]

# %%
from sklearn import tree

text_representation = tree.export_text(model)
print(text_representation)
# Out:
# |--- feature_5 <= 9.50
# |   |--- feature_8 <= 9.50
# |   |   |--- feature_9 <= 9.50
# |   |   |   |--- feature_4 <= 9.50
# |   |   |   |   |--- feature_7 <= 9.50
# |   |   |   |   |   |--- feature_1 <= 10.50
# |   |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |   |--- feature_1 >  10.50
# |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |   |--- feature_7 >  9.50
# |   |   |   |   |   |--- value: [18.00]
# |   |   |   |--- feature_4 >  9.50
# |   |   |   |   |--- value: [18.00]
# |   |   |--- feature_9 >  9.50
# |   |   |   |--- value: [18.00]
# |   |--- feature_8 >  9.50
# |   |   |--- value: [18.00]
# |--- feature_5 >  9.50
# |   |--- value: [18.00]

# %%
import graphviz # for plotting decision tree graphs
from sklearn import tree

dot_data = tree.export_graphviz(model, out_file=None,
                                feature_names=names,
                                filled=True,
                                rotate=True,
                               )

graph = graphviz.Source(dot_data)

graph

# %%
from IPython.display import Image
from sklearn import tree
import matplotlib.image as mpimg
import pydotplus
import io
import matplotlib.pyplot as plt

import sys
str1 = "/usr/local/Cellar/graphviz/2.40.1_1/bin/"
sys.path.append(str1)

dot_data = io.StringIO()
tree.export_graphviz(model, out_file=dot_data, filled=True, feature_names = names )

# Draw graph
pydotplus.graph_from_dot_data(dot_data.getvalue()).write_png('dt.png')

plt.figure(figsize=(20, 20))
img = mpimg.imread('dt.png')
imgplot = plt.imshow(img)

plt.show()

# %% [markdown]
# ## Random data

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

n=10
Nexamples=1000

X =[]
y =[]

names = ["x"+str(i) for i in range(n)]

for j in range(Nexamples):
    list1 = rnd.sample(range(1,101), n)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

for j in range(Nexamples):
    list1 = rnd.sample(range(2,201), n)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

model = DecisionTreeRegressor(max_leaf_nodes = 50).fit(X,y)

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=10000

X =[]
y =[]

for j in range(Nexamples):
    list1 = rnd.sample(range(1, 101), n)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

for j in range(Nexamples):
    list1 = rnd.sample(range(2, 201), n)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

y_pred =model.predict(X)

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred':[int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 0.956
#                                                      X    y  y_pred
# 0               [61, 79, 6, 4, 13, 87, 49, 84, 40, 62]   87      81
# 1             [43, 57, 26, 66, 82, 98, 91, 29, 17, 25]   98      96
# 2                [9, 46, 33, 45, 3, 4, 58, 77, 50, 83]   83      81
# 3               [4, 75, 9, 89, 56, 53, 23, 15, 78, 33]   89      95
# 4               [72, 31, 7, 13, 30, 97, 75, 1, 24, 83]   97      94
# ...                                                ...  ...     ...
# 19995   [50, 105, 37, 170, 109, 114, 76, 185, 58, 122]  185     186
# 19996      [104, 5, 56, 138, 33, 97, 81, 70, 109, 125]  138     153
# 19997    [44, 46, 176, 48, 127, 152, 141, 89, 110, 14]  176     178
# 19998  [148, 114, 122, 168, 93, 156, 158, 44, 80, 159]  168     165
# 19999       [48, 31, 25, 56, 20, 157, 36, 192, 67, 34]  192     194
#
# [20000 rows x 3 columns]

# %%
from sklearn import tree

text_representation = tree.export_text(model)
print(text_representation)
# Out:
# |--- feature_2 <= 100.50
# |   |--- feature_9 <= 100.50
# |   |   |--- feature_3 <= 100.50
# |   |   |   |--- feature_7 <= 100.50
# |   |   |   |   |--- feature_1 <= 102.00
# |   |   |   |   |   |--- feature_5 <= 104.00
# |   |   |   |   |   |   |--- feature_0 <= 119.50
# |   |   |   |   |   |   |   |--- feature_4 <= 107.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 89.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 88.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 87.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  87.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [96.10]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  88.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [96.31]
# |   |   |   |   |   |   |   |   |--- feature_0 >  89.50
# |   |   |   |   |   |   |   |   |   |--- value: [97.24]
# |   |   |   |   |   |   |   |--- feature_4 >  107.50
# |   |   |   |   |   |   |   |   |--- value: [145.00]
# |   |   |   |   |   |   |--- feature_0 >  119.50
# |   |   |   |   |   |   |   |--- value: [177.50]
# |   |   |   |   |   |--- feature_5 >  104.00
# |   |   |   |   |   |   |--- value: [173.92]
# |   |   |   |   |--- feature_1 >  102.00
# |   |   |   |   |   |--- feature_1 <= 126.50
# |   |   |   |   |   |   |--- feature_1 <= 118.50
# |   |   |   |   |   |   |   |--- value: [176.62]
# |   |   |   |   |   |   |--- feature_1 >  118.50
# |   |   |   |   |   |   |   |--- value: [135.60]
# |   |   |   |   |   |--- feature_1 >  126.50
# |   |   |   |   |   |   |--- value: [185.64]
# |   |   |   |--- feature_7 >  100.50
# |   |   |   |   |--- feature_7 <= 177.50
# |   |   |   |   |   |--- feature_6 <= 13.00
# |   |   |   |   |   |   |--- value: [142.67]
# |   |   |   |   |   |--- feature_6 >  13.00
# |   |   |   |   |   |   |--- feature_9 <= 24.00
# |   |   |   |   |   |   |   |--- value: [152.75]
# |   |   |   |   |   |   |--- feature_9 >  24.00
# |   |   |   |   |   |   |   |--- value: [177.81]
# |   |   |   |   |--- feature_7 >  177.50
# |   |   |   |   |   |--- value: [194.40]
# |   |   |--- feature_3 >  100.50
# |   |   |   |--- feature_3 <= 179.50
# |   |   |   |   |--- feature_8 <= 152.50
# |   |   |   |   |   |--- feature_1 <= 135.00
# |   |   |   |   |   |   |--- feature_8 <= 89.00
# |   |   |   |   |   |   |   |--- value: [176.44]
# |   |   |   |   |   |   |--- feature_8 >  89.00
# |   |   |   |   |   |   |   |--- feature_4 <= 173.50
# |   |   |   |   |   |   |   |   |--- value: [151.64]
# |   |   |   |   |   |   |   |--- feature_4 >  173.50
# |   |   |   |   |   |   |   |   |--- value: [188.50]
# |   |   |   |   |   |--- feature_1 >  135.00
# |   |   |   |   |   |   |--- value: [185.00]
# |   |   |   |   |--- feature_8 >  152.50
# |   |   |   |   |   |--- value: [188.35]
# |   |   |   |--- feature_3 >  179.50
# |   |   |   |   |--- value: [192.05]
# |   |--- feature_9 >  100.50
# |   |   |--- feature_9 <= 166.50
# |   |   |   |--- feature_4 <= 158.00
# |   |   |   |   |--- feature_0 <= 166.00
# |   |   |   |   |   |--- feature_5 <= 159.00
# |   |   |   |   |   |   |--- feature_6 <= 170.50
# |   |   |   |   |   |   |   |--- feature_7 <= 170.50
# |   |   |   |   |   |   |   |   |--- feature_8 <= 157.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 168.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 162.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [152.70]
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  162.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [177.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  168.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [182.00]
# |   |   |   |   |   |   |   |   |--- feature_8 >  157.50
# |   |   |   |   |   |   |   |   |   |--- value: [177.56]
# |   |   |   |   |   |   |   |--- feature_7 >  170.50
# |   |   |   |   |   |   |   |   |--- value: [185.64]
# |   |   |   |   |   |   |--- feature_6 >  170.50
# |   |   |   |   |   |   |   |--- value: [186.71]
# |   |   |   |   |   |--- feature_5 >  159.00
# |   |   |   |   |   |   |--- value: [189.00]
# |   |   |   |   |--- feature_0 >  166.00
# |   |   |   |   |   |--- value: [189.13]
# |   |   |   |--- feature_4 >  158.00
# |   |   |   |   |--- value: [190.03]
# |   |   |--- feature_9 >  166.50
# |   |   |   |--- value: [190.99]
# |--- feature_2 >  100.50
# |   |--- feature_2 <= 185.50
# |   |   |--- feature_7 <= 163.50
# |   |   |   |--- feature_0 <= 175.50
# |   |   |   |   |--- feature_3 <= 182.50
# |   |   |   |   |   |--- feature_8 <= 180.50
# |   |   |   |   |   |   |--- feature_9 <= 179.50
# |   |   |   |   |   |   |   |--- feature_4 <= 169.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 177.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 177.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 177.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  177.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [186.85]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  177.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [188.11]
# |   |   |   |   |   |   |   |   |--- feature_5 >  177.00
# |   |   |   |   |   |   |   |   |   |--- value: [189.21]
# |   |   |   |   |   |   |   |--- feature_4 >  169.00
# |   |   |   |   |   |   |   |   |--- value: [188.90]
# |   |   |   |   |   |   |--- feature_9 >  179.50
# |   |   |   |   |   |   |   |--- value: [191.44]
# |   |   |   |   |   |--- feature_8 >  180.50
# |   |   |   |   |   |   |--- value: [191.44]
# |   |   |   |   |--- feature_3 >  182.50
# |   |   |   |   |   |--- value: [193.03]
# |   |   |   |--- feature_0 >  175.50
# |   |   |   |   |--- value: [193.30]
# |   |   |--- feature_7 >  163.50
# |   |   |   |--- value: [191.00]
# |   |--- feature_2 >  185.50
# |   |   |--- value: [195.32]

# %%
import graphviz # for plotting decision tree graphs
from sklearn import tree

dot_data = tree.export_graphviz(model, out_file=None,
                                feature_names=names,
                                filled=True,
                                rotate=True,
                               )

graph = graphviz.Source(dot_data)

graph

# %%
from IPython.display import Image
from sklearn import tree
import matplotlib.image as mpimg
import pydotplus
import io
import matplotlib.pyplot as plt

import sys
str1 = "/usr/local/Cellar/graphviz/2.40.1_1/bin/"
sys.path.append(str1)

dot_data = io.StringIO()
tree.export_graphviz(model, out_file=dot_data, filled=True, feature_names = names )

# Draw graph
pydotplus.graph_from_dot_data(dot_data.getvalue()).write_png('dt.png')

plt.figure(figsize=(20, 20))
img = mpimg.imread('dt.png')
imgplot = plt.imshow(img)

plt.show()
